# %%
import Pkg
Pkg.activate(@__DIR__)
Pkg.instantiate()

Pkg.add("Plots")
Pkg.add("MathOptInterface")
Pkg.add("Ipopt")

using LinearAlgebra, Plots
using ProgressMeter
import ForwardDiff as FD
import Convex as cvx
import ECOS

include(joinpath(@__DIR__,"utils","fmincon.jl"))
# Out:
#   Activating environment at `~/Desktop/CMU/Term_2/16745 Optimal Control/OptimalSailboat/Project.toml`
# Precompiling project...
#   ✓ PrecompileTools
#   ✓ Libuuid_jll
#   ✓ Libmount_jll
#   ✓ libpng_jll
#   ✓ XZ_jll
#   ✓ XML2_jll
#   ✓ Zstd_jll
#   ✓ ChainRulesCore
#   ✓ Fontconfig_jll
#   ✓ Gettext_jll
#   ✓ DataStructures
#   ✓ RecipesBase
#   ✓ UnitfulLatexify
#   ✓ XSLT_jll
#   ✓ Wayland_jll
#   ✓ Libtiff_jll
#   ✓ Xorg_libxcb_jll
#   ✓ OpenSSL
#   ✓ Glib_jll
#   ✓ SortingAlgorithms
#   ✓ Xorg_libX11_jll
#   ✓ Xorg_xcb_util_jll
#   ✓ Xorg_libxkbfile_jll
#   ✓ Xorg_libXrender_jll
#   ✓ Xorg_libXext_jll
#   ✓ Xorg_libXfixes_jll
#   ✓ LogExpFunctions
#   ✓ Xorg_xcb_util_keysyms_jll
#   ✓ Xorg_xcb_util_image_jll
#   ✓ Xorg_xcb_util_renderutil_jll
#   ✓ Xorg_xcb_util_wm_jll
#   ✓ Xorg_xkbcomp_jll
#   ✓ Libglvnd_jll
#   ✓ Xorg_libXinerama_jll
#   ✓ Xorg_libXrandr_jll
#   ✓ Xorg_libXcursor_jll
#   ✓ Xorg_libXi_jll
#   ✓ Xorg_xcb_util_cursor_jll
#   ✓ Cairo_jll
#   ✓ Xorg_xkeyboard_config_jll
#   ✓ HTTP
#   ✓ GLFW_jll
#   ✓ xkbcommon_jll
#   ✓ HarfBuzz_jll
#   ✓ Vulkan_Loader_jll
#   ✓ StatsBase
#   ✓ libass_jll
#   ✓ Qt6Base_jll
#   ✓ FFMPEG_jll
#   ✓ FFMPEG
#   ✓ GR_jll
#   ✓ ColorSchemes
#   ✓ Parsers
#   ✓ PlotUtils
#   ✓ JSON
#   ✓ GR
#   ✓ RecipesPipeline
#   ✓ PlotThemes
#   ✓ Plots
#   59 dependencies successfully precompiled in 120 seconds (87 already precompiled)
#   43 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions
#    Resolving package versions...
#   No Changes to `~/Desktop/CMU/Term_2/16745 Optimal Control/OptimalSailboat/Project.toml`
#   No Changes to `~/Desktop/CMU/Term_2/16745 Optimal Control/OptimalSailboat/Manifest.toml`
# Precompiling project...
#   ✓ PrecompileTools
#   ✓ Libuuid_jll
#   ✓ Libmount_jll
#   ✓ libpng_jll
#   ✓ OpenSSL_jll
#   ✓ XZ_jll
#   ✓ XML2_jll
#   ✓ ChainRulesCore
#   ✓ Zstd_jll
#   ✓ Fontconfig_jll
#   ✓ UnitfulLatexify
#   ✓ RecipesBase
#   ✓ DataStructures
#   ✓ XSLT_jll
#   ✓ Gettext_jll
#   ✓ Wayland_jll
#   ✓ OpenSSL
#   ✓ Xorg_libxcb_jll
#   ✓ Libtiff_jll
#   ✓ SortingAlgorithms
#   ✓ Glib_jll
#   ✓ Xorg_libX11_jll
#   ✓ Xorg_xcb_util_jll
#   ✓ LogExpFunctions
#   ✓ Xorg_libxkbfile_jll
#   ✓ Xorg_libXrender_jll
#   ✓ Xorg_libXext_jll
#   ✓ Xorg_libXfixes_jll
#   ✓ Xorg_xcb_util_keysyms_jll
#   ✓ Xorg_xcb_util_image_jll
#   ✓ Xorg_xcb_util_renderutil_jll
#   ✓ Xorg_xcb_util_wm_jll
#   ✓ Xorg_xkbcomp_jll
#   ✓ Libglvnd_jll
#   ✓ Xorg_libXinerama_jll
#   ✓ Xorg_libXrandr_jll
#   ✓ HTTP
#   ✓ Xorg_libXcursor_jll
#   ✓ Xorg_libXi_jll
#   ✓ Cairo_jll
#   ✓ Xorg_xkeyboard_config_jll
#   ✓ Xorg_xcb_util_cursor_jll
#   ✓ GLFW_jll
#   ✓ xkbcommon_jll
#   ✓ HarfBuzz_jll
#   ✓ StatsBase
#   ✓ Vulkan_Loader_jll
#   ✓ libass_jll
#   ✓ ColorSchemes
#   ✓ Qt6Base_jll
#   ✓ FFMPEG_jll
#   ✓ FFMPEG
#   ✓ GR_jll
#   ✓ PlotUtils
#   ✓ Parsers
#   ✓ JSON
#   ✓ RecipesPipeline
#   ✓ PlotThemes
#   ✓ GR
#   ✓ Plots
#   60 dependencies successfully precompiled in 120 seconds (86 already precompiled)
#   44 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions
#    Resolving package versions...
#     Updating `~/Desktop/CMU/Term_2/16745 Optimal Control/OptimalSailboat/Project.toml`
#   [b8f27783] + MathOptInterface v1.29.0
#     Updating `~/Desktop/CMU/Term_2/16745 Optimal Control/OptimalSailboat/Manifest.toml`
#   [6e4b80f9] + BenchmarkTools v1.5.0
#   [523fee87] + CodecBzip2 v0.8.2
#   [bbf7d656] + CommonSubexpressions v0.3.0
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.15.1
#   [f6369f11] + ForwardDiff v0.10.36
#   [b8f27783] + MathOptInterface v1.29.0
#   [d8a4904e] + MutableArithmetics v1.4.3
#   [276daf66] + SpecialFunctions v2.3.1
#   [90137ffa] + StaticArrays v1.9.3
#   [1e83bf80] + StaticArraysCore v1.4.2
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [9abbd945] + Profile
# Precompiling project...
#   ✓ PrecompileTools
#   ✓ libpng_jll
#   ✓ OpenSSL_jll
#   ✓ Libmount_jll
#   ✓ Libuuid_jll
#   ✓ Zstd_jll
#   ✓ XZ_jll
#   ✓ XML2_jll
#   ✓ ChainRulesCore
#   ✓ Fontconfig_jll
#   ✓ RecipesBase
#   ✓ Libtiff_jll
#   ✓ OpenSSL
#   ✓ DataStructures
#   ✓ UnitfulLatexify
#   ✓ XSLT_jll
#   ✓ Wayland_jll
#   ✓ Gettext_jll
#   ✓ Xorg_libxcb_jll
#   ✓ SortingAlgorithms
#   ✓ Glib_jll
#   ✓ Xorg_libX11_jll
#   ✓ Xorg_xcb_util_jll
#   ✓ LogExpFunctions
#   ✓ Xorg_libXext_jll
#   ✓ Xorg_libxkbfile_jll
#   ✓ Xorg_libXfixes_jll
#   ✓ Xorg_libXrender_jll
#   ✓ Xorg_xcb_util_image_jll
#   ✓ Xorg_xcb_util_renderutil_jll
#   ✓ Xorg_xcb_util_wm_jll
#   ✓ Xorg_xcb_util_keysyms_jll
#   ✓ HTTP
#   ✓ Libglvnd_jll
#   ✓ Xorg_libXinerama_jll
#   ✓ Xorg_xkbcomp_jll
#   ✓ Xorg_libXi_jll
#   ✓ Xorg_libXrandr_jll
#   ✓ Xorg_libXcursor_jll
#   ✓ Cairo_jll
#   ✓ Xorg_xcb_util_cursor_jll
#   ✓ Xorg_xkeyboard_config_jll
#   ✓ StatsBase
#   ✓ GLFW_jll
#   ✓ xkbcommon_jll
#   ✓ HarfBuzz_jll
#   ✓ Vulkan_Loader_jll
#   ✓ libass_jll
#   ✓ ColorSchemes
#   ✓ Qt6Base_jll
#   ✓ FFMPEG_jll
#   ✓ StaticArrays
#   ✓ SpecialFunctions
#   ✓ FFMPEG
#   ✓ DiffRules
#   ✓ GR_jll
#   ✓ PlotUtils
#   ✓ Parsers
#   ✓ ForwardDiff
#   ✓ JSON
#   ✓ RecipesPipeline
#   ✓ BenchmarkTools
#   ✓ PlotThemes
#   ✓ GR
#   ✓ MathOptInterface
#   ✓ Plots
#   66 dependencies successfully precompiled in 138 seconds (92 already precompiled)
#   50 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions
#    Resolving package versions...
#     Updating `~/Desktop/CMU/Term_2/16745 Optimal Control/OptimalSailboat/Project.toml`
#   [b6b21f68] + Ipopt v1.6.2
#     Updating `~/Desktop/CMU/Term_2/16745 Optimal Control/OptimalSailboat/Manifest.toml`
#   [b6b21f68] + Ipopt v1.6.2
#   [ae81ac8f] + ASL_jll v0.1.3+0
#   [9cc047cb] + Ipopt_jll v300.1400.400+0
#   [d00139f3] + METIS_jll v5.1.2+0
#   [d7ed1dd3] + MUMPS_seq_jll v5.4.1+0
#   [656ef2d0] + OpenBLAS32_jll v0.3.12+1
# Precompiling project...
#   ✓ PrecompileTools
#   ✓ Libmount_jll
#   ✓ OpenSSL_jll
#   ✓ Libuuid_jll
#   ✓ libpng_jll
#   ✓ Zstd_jll
#   ✓ XZ_jll
#   ✓ XML2_jll
#   ✓ ChainRulesCore
#   ✓ Fontconfig_jll
#   ✓ RecipesBase
#   ✓ Libtiff_jll
#   ✓ OpenSSL
#   ✓ DataStructures
#   ✓ XSLT_jll
#   ✓ UnitfulLatexify
#   ✓ Wayland_jll
#   ✓ Gettext_jll
#   ✓ Xorg_libxcb_jll
#   ✓ SortingAlgorithms
#   ✓ Glib_jll
#   ✓ Xorg_libX11_jll
#   ✓ Xorg_xcb_util_jll
#   ✓ LogExpFunctions
#   ✓ Xorg_libXext_jll
#   ✓ Xorg_libxkbfile_jll
#   ✓ Xorg_libXfixes_jll
#   ✓ Xorg_libXrender_jll
#   ✓ Xorg_xcb_util_image_jll
#   ✓ Xorg_xcb_util_renderutil_jll
#   ✓ Xorg_xcb_util_wm_jll
#   ✓ Xorg_xcb_util_keysyms_jll
#   ✓ HTTP
#   ✓ Libglvnd_jll
#   ✓ Xorg_libXinerama_jll
#   ✓ Xorg_xkbcomp_jll
#   ✓ Xorg_libXi_jll
#   ✓ Xorg_libXrandr_jll
#   ✓ Xorg_libXcursor_jll
#   ✓ Xorg_xcb_util_cursor_jll
#   ✓ Cairo_jll
#   ✓ Xorg_xkeyboard_config_jll
#   ✓ GLFW_jll
#   ✓ StatsBase
#   ✓ xkbcommon_jll
#   ✓ HarfBuzz_jll
#   ✓ Vulkan_Loader_jll
#   ✓ ColorSchemes
#   ✓ libass_jll
#   ✓ Qt6Base_jll
#   ✓ FFMPEG_jll
#   ✓ StaticArrays
#   ✓ SpecialFunctions
#   ✓ FFMPEG
#   ✓ DiffRules
#   ✓ GR_jll
#   ✓ PlotUtils
#   ✓ Parsers
#   ✓ ForwardDiff
#   ✓ JSON
#   ✓ RecipesPipeline
#   ✓ BenchmarkTools
#   ✓ PlotThemes
#   ✓ GR
#   ✓ MathOptInterface
#   ✓ Plots

# %%
"""
Converts from cartesian (x,y) to polar (r,θ) coordinates.
"""
function car2pol(x, y)
    r = √(x^2 + y^2)
    θ = atan(y, x)
    return r, θ
end;

"""
Wraps an angle (in radians) to the range [-π, π].
"""
function wrap2pi(θ)
    return θ - 2*π*floor((θ+π)/(2*π))
end;

"""
Converts from a vector of vectors to a matrix.
"""
function vec2mat(X::Vector{Vector{Float64}})::Matrix
    # convert a vector of vectors to a matrix 
    Xm = hcat(X...)
    return Xm 
end;

"""
Converts from a matrix to a vector of vectors.
"""
function mat2vec(Xm::Matrix)::Vector{Vector{Float64}}
    # convert a matrix into a vector of vectors 
    X = [Xm[:,i] for i = 1:size(Xm,2)]
    return X 
end;

# %% [markdown]
# A linear quadratic regulator (LQR) will be used to control the roll motion. The first step is thus to make a linearized system of the roll motion about an equilibrium point, which is selected to be the desired heel angle. The linearized system can be written as:
#
# $$ x = \begin{bmatrix} \phi \\ p \end{bmatrix} (64) $$
#
# $$\dot{x} = Ax + Bu. (65)$$
#
# The restoring moment when linearised becomes:
# $$ G_{\phi} = \rho_w g \nabla GM_t((1 - 2\sin(\phi_w))^2) \phi + C_1 $$
#
# where $\rho_w$ is sea water density, g is gravity, $\nabla$ is the total displacement of the ship, $GM_t$ is the transerse metacentric heigh, $ \phi_w $ is the equilibrium point
#
# and $C_1$ is equal to
#
# $$ C_1 = \rho_w g \nabla GM_t\cos(\phi_w)\sin(\phi_w) $$
#
# Making C1 and the moment generated by the keel a part of our control input u linearizes the system, and the linearized system model do then only includes the restoring moment. Matrices A and B in our linearized system then becomes:
#
# $$
# A = \begin{bmatrix}
# 0 & 1 \\
# \frac{-\rho_w g \nabla GM_t(1 - 2\sin(\phi_w))^2}{I_{xx} - K_{\dot{p}}} & 0
# \end{bmatrix}
#
# B = \begin{bmatrix}
# 0 \\
# \frac{1}{I_{xx} - K_{\dot{p}}}
# \end{bmatrix},
# $$
# where u is defined as
# $$
# u = -K \begin{bmatrix}
# \phi - \phi_d \\
# p
# \end{bmatrix}
# - K_i \int_0^t \phi - \phi_d d\tau + C_1 + F_{uh}z.
# $$

# %%
m = 1600 # kg
ρ = 1020 # kg/m3
g = 9.81 # m/s2
GMₜ = 2.4 # m
Ixx = 6.8e3 # kg m2
Kₚ = -1.0e3 # kg m2
∇ = m/ρ
# Out:
# UndefVarError: $ not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/CMU/Term_2/16745 Optimal Control/OptimalSailboat/roll_controller.ipynb:1

# %%
Q = [0.75 0; 0 1]
R = 1e-10
A = [0 1; 0 0]

ϕw = x[2]

A[1,2] = -ρ*g*GMₜ(1-2*sin(ϕw))^2/(Ixx - Kₚ)

B = [0; 1/(Ixx - Kp)]

# %%
function FHLQR_solver(A::Matrix, B::Matrix, Q::Matrix, R::Matrix, Qf::Matrix, N::Int64)::Tuple{Vector{Matrix{Float64}}, Vector{Matrix{Float64}}}
    """
    Solves the continuous-time LQR problem.
    """

    nx,nu = size(B)
    @assert size(A) == (nx, nx)
    @assert size(Q) == (nx, nx)
    @assert size(R) == (nu, nu)
    @assert size(Qf) == (nx, nx)
    
    # instantiate S and K
    P = [zeros(nx,nx) for i = 1:N]
    K = [zeros(nu,nx) for i = 1:N-1]
    # initialize S[N] with Qf
    P[N] = deepcopy(Qf)

    for k = N:-1:2
        K[k-1] = (R + B'*P[k]*B)\(B'*P[k]*A)
        P[k-1] = Q + (A-B*K[k-1])'*P[k]*(A-B*K[k-1]) + K[k-1]'*R*K[k-1]
    end
    return K, P
end


function control(K::Vector{Matrix{Float64}}, x::Vector{Float64}, Ki = 3500)
    integral = 
    u = -K*x + Ki
# Out:
# FHLQR_solver (generic function with 1 method)
